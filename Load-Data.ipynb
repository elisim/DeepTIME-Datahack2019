# %%
import matplotlib
# %matplotlib inline

# %%
from data import Images
with Images('data/images.tar') as images:
    path = images.paths[0]
    image = images[path]
    print('read image "{}"" of shape {}'.format(path, image.shape))
# Out:
# read image "person_0000/video_0002/seq_0000/frame_00000.jpg"" of shape (64, 64, 3)

# %%
from utils import *
show_numpy_image(image)
